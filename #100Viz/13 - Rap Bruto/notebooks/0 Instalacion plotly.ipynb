# %%
# instalacion
# !conda install -c plotly plotly=3.3.0 -y

### Avoid "JavaScript heap out of memory" errors during extension installation
# !export NODE_OPTIONS=--max-old-space-size=4096

### figureWidget support
# !jupyter labextension install plotlywidget@0.4.0

### Unset NODE_OPTIONS environment variable
# !unset NODE_OPTIONS
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.8
#   latest version: 4.5.11
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - plotly=3.3.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     retrying-1.3.3             |             py_2          11 KB  conda-forge
#     plotly-3.3.0               |           py36_0        27.7 MB  plotly
#     ------------------------------------------------------------
#                                            Total:        27.7 MB
#
# The following NEW packages will be INSTALLED:
#
#     plotly:   3.3.0-py36_0 plotly
#     retrying: 1.3.3-py_2   conda-forge
#
#
# Downloading and Extracting Packages
# retrying-1.3.3       |   11 KB | ####################################### | 100%
# plotly-3.3.0         | 27.7 MB | ####################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# > /opt/conda/bin/npm pack plotlywidget@0.4.0
# plotlywidget-0.4.0.tgz
# > node /opt/conda/lib/python3.6/site-packages/jupyterlab/staging/yarn.js install
# yarn install v1.9.4
# info No lockfile found.
# [1/4] Resolving packages...
# ⠁ ⠂ @jupyterlab/application@^0.18.2⠄ @jupyterlab/application@^0.18.2⡀ @jupyterlab/application@^0.18.2⢀ @jupyterlab/application@^0.18.2⠠ @jupyterlab/application@^0.18.2⠐ @jupyterlab/application@^0.18.2⠈ @jupyterlab/application@^0.18.2⠁ @phosphor/widgets@^1.6.0⠂ @phosphor/signaling@^1.2.2⠄ @phosphor/algorithm@^1.1.2⡀ @phosphor/collections@^1.1.2⢀ @phosphor/virtualdom@^1.1.2⠠ marked@~0.4.0⠐ xtend@^4.0.0⠈ json-parser@^1.0.0⠁ js-tokens@^3.0.0 || ^4.0.0⠂ whatwg-fetch@>=0.10.0⠄ codemirror@~5.39.0⡀ entities@~1.1.1⢀ safer-buffer@>= 2.1.2 < 3⠠ safer-buffer@>= 2.1.2 < 3⠐ safer-buffer@>= 2.1.2 < 3⠈ safer-buffer@>= 2.1.2 < 3⠁ @jupyterlab/application-extension@^0.18.2⠂ @jupyterlab/application-extension@^0.18.2⠄ @jupyterlab/application-extension@^0.18.2⡀ @jupyterlab/application-extension@^0.18.2⢀ @jupyterlab/application-extension@^0.18.2⠠ @jupyterlab/apputils-extension@^0.18.2⠐ @jupyterlab/apputils-extension@^0.18.2⠈ @jupyterlab/apputils-extension@^0.18.2⠁ @jupyterlab/apputils-extension@^0.18.2⠂ es6-promise@~4.1.1⠄ es6-promise@~4.1.1⡀ es6-promise@~4.1.1⢀ es6-promise@~4.1.1⠠ es6-promise@~4.1.1⠐ @jupyterlab/attachments@^0.18.2⠈ @jupyterlab/attachments@^0.18.2⠁ @jupyterlab/attachments@^0.18.2⠂ @jupyterlab/attachments@^0.18.2⠄ @jupyterlab/cells@^0.18.2⡀ @jupyterlab/cells@^0.18.2⢀ @jupyterlab/cells@^0.18.2⠠ @jupyterlab/cells@^0.18.2⠐ react@~16.4.0⠈ react@~16.4.0⠁ react@~16.4.0⠂ react@~16.4.0⠄ react@~16.4.0⡀ @jupyterlab/codemirror-extension@^0.18.2⢀ @jupyterlab/codemirror-extension@^0.18.2⠠ codemirror@~5.39.0⠐ codemirror@~5.39.0⠈ codemirror@~5.39.0⠁ codemirror@~5.39.0⠂ codemirror@~5.39.0⠄ @jupyterlab/completer@^0.18.2⡀ @jupyterlab/completer@^0.18.2⢀ @jupyterlab/completer@^0.18.2⠠ @jupyterlab/completer@^0.18.2⠐ @jupyterlab/completer-extension@^0.18.2⠈ @jupyterlab/completer-extension@^0.18.2⠁ @jupyterlab/completer-extension@^0.18.2⠂ @jupyterlab/completer-extension@^0.18.2⠄ @jupyterlab/completer-extension@^0.18.2⡀ @phosphor/widgets@^1.6.0⢀ @phosphor/widgets@^1.6.0⠠ @phosphor/widgets@^1.6.0⠐ @phosphor/widgets@^1.6.0⠈ react@~16.4.0⠁ @jupyterlab/console-extension@^0.18.2⠂ @jupyterlab/console-extension@^0.18.2⠄ @jupyterlab/console-extension@^0.18.2⡀ @jupyterlab/console-extension@^0.18.2⢀ @phosphor/widgets@^1.6.0⠠ @phosphor/widgets@^1.6.0⠐ @phosphor/widgets@^1.6.0⠈ @phosphor/widgets@^1.6.0⠁ @phosphor/widgets@^1.6.0⠂ react@~16.4.0⠄ react@~16.4.0⡀ react@~16.4.0⢀ react@~16.4.0⠠ @jupyterlab/csvviewer@^0.18.2⠐ @phosphor/widgets@^1.6.0⠈ @jupyterlab/docmanager-extension@^0.18.2⠁ @jupyterlab/docmanager-extension@^0.18.2⠂ @jupyterlab/docmanager-extension@^0.18.2⠄ @jupyterlab/docmanager-extension@^0.18.2⡀ @jupyterlab/docmanager-extension@^0.18.2⢀ @jupyterlab/extensionmanager@^0.18.2⠠ @jupyterlab/extensionmanager@^0.18.2⠐ @jupyterlab/extensionmanager@^0.18.2⠈ @jupyterlab/extensionmanager@^0.18.2⠁ semver@^5.5.0⠂ @jupyterlab/extensionmanager-extension@^0.18.2⠄ @jupyterlab/extensionmanager-extension@^0.18.2⡀ @jupyterlab/extensionmanager-extension@^0.18.2⢀ @jupyterlab/extensionmanager-extension@^0.18.2⠠ @jupyterlab/faq-extension@^0.18.2⠐ @jupyterlab/faq-extension@^0.18.2⠈ @jupyterlab/faq-extension@^0.18.2⠁ @jupyterlab/faq-extension@^0.18.2⠂ @jupyterlab/faq-extension@^0.18.2⠄ @jupyterlab/filebrowser-extension@^0.18.3⡀ @jupyterlab/filebrowser-extension@^0.18.3⢀ @jupyterlab/filebrowser-extension@^0.18.3⠠ @jupyterlab/filebrowser-extension@^0.18.3⠐ @jupyterlab/fileeditor-extension@^0.18.2⠈ @jupyterlab/fileeditor-extension@^0.18.2⠁ @jupyterlab/fileeditor-extension@^0.18.2⠂ @jupyterlab/fileeditor-extension@^0.18.2⠄ @jupyterlab/fileeditor-extension@^0.18.2⡀ @jupyterlab/help-extension@^0.18.2⢀ @jupyterlab/help-extension@^0.18.2⠠ @jupyterlab/help-extension@^0.18.2⠐ @jupyterlab/help-extension@^0.18.2⠈ @jupyterlab/imageviewer@^0.18.2⠁ @jupyterlab/imageviewer@^0.18.2⠂ @jupyterlab/imageviewer@^0.18.2⠄ @jupyterlab/imageviewer@^0.18.2⡀ @jupyterlab/imageviewer@^0.18.2⢀ @jupyterlab/imageviewer-extension@^0.18.2⠠ @jupyterlab/imageviewer-extension@^0.18.2⠐ @jupyterlab/imageviewer-extension ...
# ⡀ escodegen@^1.8.1⢀ strip-bom-string@^1.0.0⠠ ndarray-linear-interpolate@^1.0.0⠐ two-sum@^1.0.0⠈ mumath@^3.3.4⠁ robust-determinant@^1.1.0⠂ es5-ext@^0.10.9⠄ is-finite@^1.0.1⡀ is-callable@^1.1.3⢀ path-is-absolute@^1.0.0warning plotlywidget > plotly.js > ndarray-fill > cwise > static-module > through2 > xtend > object-keys@0.4.0:
# ⠠ minimist@0.0.8⠐ gl-mat4@^1.0.1⠈ vlq@^1.0.0⠁ typedarray-pool@^1.0.0⠂ two-product@^1.0.0⠄ vlq@^0.2.2⡀ sprintf-js@~1.0.2⢀ acorn@^5.0.0⠠ through@2⠐ robust-orientation@^1.1.3⠈ concat-map@0.0.1⠁ has-symbols@^1.0.0⠂ color-name@1.1.3⠄ color-name@1.1.3⡀ color-name@1.1.3⢀ color-name@1.1.3⠠ color-name@1.1.3⠐ color-name@1.1.3⠈ color-name@1.1.3⠁ color-name@1.1.3⠂ color-name@1.1.3⠄ color-name@1.1.3⡀ color-name@1.1.3⢀ color-name@1.1.3⠠ color-name@1.1.3⠐ color-name@1.1.3⠈ color-name@1.1.3⠁ color-name@1.1.3⠂ color-name@1.1.3⠄ color-name@1.1.3⡀ color-name@1.1.3⢀ color-name@1.1.3⠠ color-name@1.1.3⠐ color-name@1.1.3⠈ color-name@1.1.3⠁ color-name@1.1.3⠂ color-name@1.1.3⠄ color-name@1.1.3⡀ color-name@1.1.3⢀ color-name@1.1.3⠠ color-name@1.1.3⠐ color-name@1.1.3⠈ color-name@1.1.3⠁ color-name@1.1.3⠂ color-name@1.1.3⠄ color-name@1.1.3⡀ color-name@1.1.3⢀ color-name@1.1.3⠠ color-name@1.1.3⠐ color-name@1.1.3⠈ color-name@1.1.3⠁ color-name@1.1.3⠂ color-name@1.1.3⠄ color-name@1.1.3⡀ color-name@1.1.3⢀ color-name@1.1.3⠠ color-name@1.1.3⠐ color-name@1.1.3⠈ color-name@1.1.3⠁ color-name@1.1.3⠂ color-name@1.1.3⠄ color-name@1.1.3⡀ color-name@1.1.3⢀ color-name@1.1.3⠠ color-name@1.1.3⠐ color-name@1.1.3⠈ color-name@1.1.3⠁ color-name@1.1.3⠂ color-name@1.1.3⠄ color-name@1.1.3⡀ semver@^5.1.0⢀ underscore@^1.8.3⠠ @jupyterlab/buildutils@^0.9.2⠐ @jupyterlab/buildutils@^0.9.2⠈ @jupyterlab/buildutils@^0.9.2⠁ @jupyterlab/buildutils@^0.9.2⠂ typescript@~2.9.2⠄ graceful-fs@^4.1.6⡀ escape-string-regexp@^1.0.5⢀ url-to-options@^1.0.1⠠ is-object@^1.0.1⠐ has-symbol-support-x@^1.4.1⠈ css-loader@~0.28.7⠁ postcss-zindex@^2.0.1⠂ postcss@^6.0.1⠄ uniqs@^2.0.0⡀ postcss@^5.0.5⢀ ansi-regex@^2.0.0warning css-loader > cssnano > autoprefixer > browserslist@1.7.7: Browserslist 2 could fail on reading Browserslist >3.0 config used in other tools.
# warning css-loader > cssnano > postcss-merge-rules > browserslist@1.7.7: Browserslist 2 could fail on reading Browserslist >3.0 config used in other tools.
# ⠠ electron-to-chromium@^1.2.7⠐ q@^1.1.2⠈ chalk@^1.1.3⠁ chalk@^1.1.3⠂ chalk@^1.1.3⠄ chalk@^1.1.3⡀ chalk@^1.1.3⢀ chalk@^1.1.3⠠ chalk@^1.1.3⠐ chalk@^1.1.3⠈ chalk@^1.1.3⠁ chalk@^1.1.3warning css-loader > cssnano > postcss-merge-rules > caniuse-api > browserslist@1.7.7: Browserslist 2 could fail on reading Browserslist >3.0 config used in other tools.
# ⠂ semver@^5.4.1⠄ schema-utils@^0.4.5⡀ punycode@^2.1.0⢀ source-map@~0.6.1⠠ object-assign@^4.1.1⠐ upper-case@^1.1.1⠈ html-webpack-plugin@~3.2.0⠁ renderkid@^2.0.1⠂ domelementtype@1⠄ raw-loader@~0.5.1⡀ style-loader@~0.21.0⢀ uglifyjs-webpack-plugin@~1.2.5⠠ p-try@^1.0.0⠐ run-queue@^1.0.0⠈ url-loader@~1.0.1⠁ webpack@~4.12.0⠂ worker-farm@^1.5.2⠄ readable-stream@^2.0.1⡀ mamacro@^0.0.3⢀ is-descriptor@^1.0.0⠠ date-now@^0.1.4⠐ @webassemblyjs/wast-printer@1.5.12⠈ urix@^0.1.0⠁ safe-buffer@^5.1.0⠂ kind-of@^3.0.2⠄ safe-buffer@^5.1.2⡀ isobject@^3.0.0⢀ minimalistic-crypto-utils@^1.0.1⠠ osenv@^0.1.4⠐ minipass@^2.2.1⠈ minimatch@^3.0.4⠁ minimatch@^3.0.4⠂ minimatch@^3.0.4⠄ minimatch@^3.0.4⡀ minimatch@^3.0.4⢀ minimatch@^3.0.4⠠ minimatch@^3.0.4⠐ minimatch@^3.0.4⠈ minimatch@^3.0.4⠁ minimatch@^3.0.4⠂ minimatch@^3.0.4⠄ minimatch@^3.0.4⡀ minimatch@^3.0.4⢀ minimatch@^3.0.4⠠ minimatch@^3.0.4⠐ minimatch@^3.0.4⠈ minimatch@^3.0.4⠁ minimatch@^3.0.4⠂ minimatch@^3.0.4⠄ webpack-cli@^3.0.3⡀ find-up@^3.0.0⢀ webpack-merge@^4.1.1[2/4] Fetching packages...
# [----------------------------------------------------------------------] 0/1195[##-------------------------------------------------------------------] 26/1195[##-------------------------------------------------------------------] 41/1195[####-----------------------------------------------------------------] 62/1195[######--------------------------------------------------------------] 102/1195[########------------------------------------------------------------] 138/1195[###########---------------------------------------------------------] 189/1195[##############------------------------------------------------------] 238/1195[#################---------------------------------------------------] 301/1195[#####################-----------------------------------------------] 370/1195[##########################------------------------------------------] 449/1195[##############################--------------------------------------] 533/1195[#################################-----------------------------------] 588/1195[#####################################-------------------------------] 651/1195[########################################----------------------------] 706/1195[############################################------------------------] 778/1195[################################################--------------------] 845/1195[###################################################-----------------] 891/1195[#####################################################---------------] 932/1195[#######################################################-------------] 973/1195[#########################################################----------] 1025/1195[############################################################-------] 1077/1195[###############################################################----] 1128/1195[################################################################---] 1148/1195[###################################################################] 1192/1195[###################################################################] 1194/1195info fsevents@1.2.4: The platform "linux" is incompatible with this module.
# info "fsevents@1.2.4" is an optional dependency and failed compatibility check. Excluding it from installation.
# [3/4] Linking dependencies...
# warning "@jupyterlab/vdom-extension > @nteract/transform-vdom@1.1.1" has incorrect peer dependency "react@^15.6.1".
# [###################################################################] 1195/1195[----------------------------------------------------------------------] 0/1232[---------------------------------------------------------------------] 0/24450[-------------------------------------------------------------------] 128/24450[#------------------------------------------------------------------] 371/24450[#------------------------------------------------------------------] 510/24450[##-----------------------------------------------------------------] 758/24450[##-----------------------------------------------------------------] 884/24450[###---------------------------------------------------------------] 1134/24450[####--------------------------------------------------------------] 1380/24450[####--------------------------------------------------------------] 1510/24450[####--------------------------------------------------------------] 1657/24450[#####-------------------------------------------------------------] 1888/24450[######------------------------------------------------------------] 2129/24450[######------------------------------------------------------------] 2291/24450[#######-----------------------------------------------------------] 2516/24450[#######-----------------------------------------------------------] 2755/24450[########----------------------------------------------------------] 3015/24450[#########---------------------------------------------------------] 3266/24450[##########--------------------------------------------------------] 3531/24450[##########--------------------------------------------------------] 3771/24450[###########-------------------------------------------------------] 4015/24450[############------------------------------------------------------] 4269/24450[############------------------------------------------------------] 4552/24450[#############-----------------------------------------------------] 4812/24450[##############----------------------------------------------------] 5135/24450[##############----------------------------------------------------] 5343/24450[###############---------------------------------------------------] 5640/24450[################--------------------------------------------------] 5886/24450[################--------------------------------------------------] 6092/24450[#################-------------------------------------------------] 6272/24450[##################------------------------------------------------] 6514/24450[##################------------------------------------------------] 6779/24450[###################-----------------------------------------------] 7023/24450[####################----------------------------------------------] 7274/24450[####################----------------------------------------------] 7533/24450[#####################---------------------------------------------] 7762/24450[######################--------------------------------------------] 8030/24450[######################--------------------------------------------] 8209/24450[#######################-------------------------------------------] 8519/24450[########################------------------------------------------] 8724/24450[########################------------------------------------------] 9015/24450[#########################-----------------------------------------] 9172/24450[#########################-----------------------------------------] 9439/24450[##########################----------------------------------------] 9732/24450[###########################--------------------------------------] 10024/24450[###########################--------------------------------------] 10178/24450[############################-------------------------------------] 10424/24450[############################-------------------------------------] 10667/24450[#############################------------------------------------] 10950/24450[##############################------------------- ...
# [#####################################------------------------------] 1278/2291success Saved lockfile.
# warning Your current version of Yarn is out of date. The latest version is "1.10.1", while you're on "1.9.4".
# Done in 39.09s.
# > node /opt/conda/lib/python3.6/site-packages/jupyterlab/staging/yarn.js run build
# yarn run v1.9.4
# $ webpack
# Hash: fa28c24908ee4ca3f66f
# Version: webpack 4.12.2
# Time: 24847ms
# Built at: 2018-10-05 17:13:15
#                                                              Asset       Size                                  Chunks             Chunk Names
#                                          1.055322dcf6c2bb19185f.js    888 KiB                                       1  [emitted]
#                               674f50d287a8c48dc19ba404d20fe713.eot    162 KiB                                          [emitted]
#                               912ec66d7572ff821749319396470bde.svg    434 KiB                                          [emitted]
#                              fee66e712a8a08eef5805a46892932ad.woff   95.7 KiB                                          [emitted]
#                               b06871f281fee6b241d60582ae9369b9.ttf    162 KiB                                          [emitted]
#                                       main.ef6e1f37e01d8f17bb8c.js   55.4 KiB                                    main  [emitted]  main
#                                          0.cc98107762fcc28532b3.js    4.5 KiB                                       0  [emitted]
#                                       vega.0cdd647175d9a6042e69.js  517 bytes                                    vega  [emitted]  vega
#     vendors~@jupyter-widgets/controls~vega.3dd933b62461edbc58d8.js   22.6 KiB  vendors~@jupyter-widgets/controls~vega  [emitted]  vendors~@jupyter-widgets/controls~vega
#                               vendors~main.9fec4f9d5e676657d323.js   14.7 MiB                            vendors~main  [emitted]  vendors~main
#                               vendors~vega.a45e506cc291e9ad3a61.js   2.82 MiB                            vendors~vega  [emitted]  vendors~vega
#                             af7ae505a9eed503f8b8e6982036873e.woff2   75.4 KiB                                          [emitted]
#          vendors~@jupyter-widgets/controls.ea199c579095c8f0c80d.js    287 KiB       vendors~@jupyter-widgets/controls  [emitted]  vendors~@jupyter-widgets/controls
#                                   main.ef6e1f37e01d8f17bb8c.js.map     65 KiB                                    main  [emitted]  main
#                                      0.cc98107762fcc28532b3.js.map   5.73 KiB                                       0  [emitted]
#                                   vega.0cdd647175d9a6042e69.js.map  251 bytes                                    vega  [emitted]  vega
# vendors~@jupyter-widgets/controls~vega.3dd933b62461edbc58d8.js.map   15.6 KiB  vendors~@jupyter-widgets/controls~vega  [emitted]  vendors~@jupyter-widgets/controls~vega
#                           vendors~main.9fec4f9d5e676657d323.js.map   17.4 MiB                            vendors~main  [emitted]  vendors~main
#                           vendors~vega.a45e506cc291e9ad3a61.js.map   2.23 MiB                            vendors~vega  [emitted]  vendors~vega
#                                      1.055322dcf6c2bb19185f.js.map   1.04 MiB                                       1  [emitted]
#      vendors~@jupyter-widgets/controls.ea199c579095c8f0c80d.js.map    329 KiB       vendors~@jupyter-widgets/controls  [emitted]  vendors~@jupyter-widgets/controls
#                                                         index.html   1.53 KiB                                          [emitted]
# Entrypoint main = vendors~main.9fec4f9d5e676657d323.js vendors~main.9fec4f9d5e676657d323.js.map main.ef6e1f37e01d8f17bb8c.js main.ef6e1f37e01d8f17bb8c.js.map
# [0] multi whatwg-fetch ./build/index.out.js 40 bytes {main} [built]
# [1] vertx (ignored) 15 bytes {main} [optional] [built]
# [2] util (ignored) 15 bytes {main} [built]
# [3] util (ignored) 15 bytes {main} [built]
# [4] buffer (ignored) 15 bytes {main} [optional] [built]
# [5] crypto (ignored) 15 bytes {main} [optional] [built]
# [6] readable-stream (ignored) 15 bytes {main} [built]
# [7] node-fetch (ignored) 15 bytes {vega} [built]
# [8] fs (ignored) 15 bytes {vega} [built]
# [ANye] ./build/index.out.js 37.2 KiB {main} [built]
# [RnhZ] ./node_modules/moment/locale sync ^\.\/.*$ 2.88 KiB {main} [optional] [built]
# [YuTi] (webpack)/buildin/module.js 497 bytes {vendors~main} [built]
# [eTbV] ./node_modules/codemirror/mode sync ^\.\/.*\.js$ 2.78 KiB {0} [built]
# [yLpj] (webpack)/buildin/global.js 489 bytes {vendors~main} [built]
#     + 2400 hidden modules
# Child html-webpack-plugin for "index.html":
#      1 asset
#     Entrypoint undefined = index.html
#     [KTNU] ./node_modules/html-loader!./templates/partial.html 567 bytes {0} [built]
#     [YuTi] (webpack)/buildin/module.js 497 bytes {0} [built]
#     [aS2v] ./node_modules/html-webpack-plugin/lib/loader.js!./templates/template.html 1.22 KiB {0} [built]
#     [yLpj] (webpack)/buildin/global.js 489 bytes {0} [built]
#         + 1 hidden module
# Done in 28.09s.
